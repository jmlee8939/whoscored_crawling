# %%
import time
import pandas as pd
import numpy as np
import time
import pickle
from selenium import webdriver

# %% [markdown]
# ## 리그 별 2부 및 1부 경기 table

# %%
driver = webdriver.Chrome('C:/Users/jaemini_man/Desktop/soccer/chromedriver')
driver.implicitly_wait(3)
driver.get('https:/1xbet.whoscored.com/')
driver.implicitly_wait(3)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-2-e824c59d265f> in <module>
# ----> 1 driver = webdriver.Chrome('C:/Users/jaemini_man/Desktop/soccer/chromedriver')
#       2 driver.implicitly_wait(3)
#       3 driver.get('https:/1xbet.whoscored.com/')
#       4 driver.implicitly_wait(3)
#       5 driver.close()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ...

# %%
URL = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/8228/England-Premier-League'

# %%
def league_table(URL, api_delay_term=5):
    url = str(URL)
    driver = webdriver.Chrome('C:/Users/jaemini_man/Desktop/soccer/chromedriver')
    driver.get(url)
    
    time.sleep(api_delay_term)
    
    league_table_df = pd.DataFrame(columns=[
        "team_number", "team_name", "P", "W", "D", "L", "GF", "GA", "GD", "Pts"])
    elements = driver.find_elements_by_class_name('standings')[0].find_elements_by_css_selector("tr")
    
    for element in elements:
        league_table_dict = { 
            "team_number": element.find_elements_by_css_selector("td")[0].find_elements_by_css_selector("a")[0].get_attribute("href").split("/")[4], 
            "team_name": element.find_elements_by_css_selector("td")[0].find_elements_by_css_selector("a")[0].text,     
            "P": element.find_elements_by_css_selector("td")[1].text,
            "W": element.find_elements_by_css_selector("td")[2].text, 
            "D": element.find_elements_by_css_selector("td")[3].text,
            "L": element.find_elements_by_css_selector("td")[4].text, 
            "GF": element.find_elements_by_css_selector("td")[5].text, 
            "GA": element.find_elements_by_css_selector("td")[6].text,
            "GD": element.find_elements_by_css_selector("td")[7].text,
            "Pts": element.find_elements_by_css_selector("td")[8].text,
        }
        league_table_df.loc[len(league_table_df)] = league_table_dict
    
    # close webdriver
    driver.close()
    
    return league_table_df

# %%
dd = league_table(URL)

# %%
#standings-18685

# %%
league_season_URL = {}
# PL
league_season_URL['PL_1_1112'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/2935/England-Premier-League'
league_season_URL['PL_1_1213'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/3389/England-Premier-League'
league_season_URL['PL_1_1314'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/3853/England-Premier-League'
league_season_URL['PL_1_1415'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/4311/England-Premier-League'
league_season_URL['PL_1_1516'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/5826/England-Premier-League'
league_season_URL['PL_1_1617'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/6335/England-Premier-League'
league_season_URL['PL_1_1718'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/6829/England-Premier-League'
league_season_URL['PL_1_1819'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/7361/England-Premier-League'
league_season_URL['PL_1_1920'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/7811/England-Premier-League'
league_season_URL['PL_1_2021'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/2/Seasons/8228/England-Premier-League'

league_season_URL['PL_2_1112'] = "https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/2936/Stages/5477/Show/England-Championship-2011-2012"
league_season_URL['PL_2_1213'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/3390/Stages/6532/Show/England-Championship-2012-2013'
league_season_URL['PL_2_1314'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/3859/Stages/7800/Show/England-Championship-2013-2014'
league_season_URL['PL_2_1415'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/4312/Stages/9156/Show/England-Championship-2014-2015'
league_season_URL['PL_2_1516'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/5827/Stages/12497/Show/England-Championship-2015-2016'
league_season_URL['PL_2_1617'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/6365/Stages/13832/Show/England-Championship-2016-2017'
league_season_URL['PL_2_1718'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/6848/Stages/15177/Show/England-Championship-2017-2018'
league_season_URL['PL_2_1819'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/7379/Stages/16389/Show/England-Championship-2018-2019'
league_season_URL['PL_2_1920'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/7840/Stages/17629/Show/England-Championship-2019-2020'
league_season_URL['PL_2_2021'] = 'https://1xbet.whoscored.com/Regions/252/Tournaments/7/Seasons/8304/Stages/18825/Show/England-Championship-2020-2021'

## LIGA

league_season_URL['LIGA_1_1112'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/3004/Spain-LaLiga'
league_season_URL['LIGA_1_1213'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/3470/Spain-LaLiga'
league_season_URL['LIGA_1_1314'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/3922/Spain-LaLiga'
league_season_URL['LIGA_1_1415'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/5435/Spain-LaLiga'
league_season_URL['LIGA_1_1516'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/5933/Spain-LaLiga'
league_season_URL['LIGA_1_1617'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/6436/Spain-LaLiga'
league_season_URL['LIGA_1_1718'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/6960/Spain-LaLiga'
league_season_URL['LIGA_1_1819'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/7466/Spain-LaLiga'
league_season_URL['LIGA_1_1920'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/7889/Spain-LaLiga'
league_season_URL['LIGA_1_2021'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/4/Seasons/8321/Spain-LaLiga'

league_season_URL['LIGA_2_1112'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/3007/Stages/5580/Show/Spain-Segunda-Divisi%C3%B3n-2011-2012"
league_season_URL['LIGA_2_1213'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/3471/Stages/6653/Show/Spain-Segunda-Divisi%C3%B3n-2012-2013"
league_season_URL['LIGA_2_1314'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/3923/Stages/7922/Show/Spain-Segunda-Divisi%C3%B3n-2013-2014"
league_season_URL['LIGA_2_1415'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/5438/Stages/11366/Show/Spain-Segunda-Divisi%C3%B3n-2014-2015"
league_season_URL['LIGA_2_1516'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/5940/Stages/12662/Show/Spain-Segunda-Divisi%C3%B3n-2015-2016"
league_season_URL['LIGA_2_1617'] = 'https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/6441/Stages/13960/Show/Spain-Segunda-Divisi%C3%B3n-2016-2017'
league_season_URL['LIGA_2_1718'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/6961/Stages/15376/Show/Spain-Segunda-Divisi%C3%B3n-2017-2018"
league_season_URL['LIGA_2_1819'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/7467/Stages/16547/Show/Spain-Segunda-Divisi%C3%B3n-2018-2019"
league_season_URL['LIGA_2_1920'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/7890/Stages/17703/Show/Spain-Segunda-Divisi%C3%B3n-2019-2020"
league_season_URL['LIGA_2_2021'] = "https://1xbet.whoscored.com/Regions/206/Tournaments/63/Seasons/8322/Stages/18852/Show/Spain-Segunda-Divisi%C3%B3n-2020-2021"

#### SE

league_season_URL['SE_1_1112'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/3054/Italy-Serie-A'
league_season_URL['SE_1_1213'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/3512/Italy-Serie-A'
league_season_URL['SE_1_1314'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/3978/Italy-Serie-A'
league_season_URL['SE_1_1415'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/5441/Italy-Serie-A'
league_season_URL['SE_1_1516'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/5970/Italy-Serie-A'
league_season_URL['SE_1_1617'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/6461/Italy-Serie-A'
league_season_URL['SE_1_1718'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/6974/Italy-Serie-A'
league_season_URL['SE_1_1819'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/7468/Italy-Serie-A'
league_season_URL['SE_1_1920'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/7928/Italy-Serie-A'
league_season_URL['SE_1_2021'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/8330/Italy-Serie-A'

league_season_URL['SE_2_1112'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/3060/Stages/5692/Show/Italy-Serie-B-2011-2012'
league_season_URL['SE_2_1213'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/3521/Stages/6768/Show/Italy-Serie-B-2012-2013'
league_season_URL['SE_2_1314'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/3979/Stages/8021/Show/Italy-Serie-B-2013-2014'
league_season_URL['SE_2_1415'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/5442/Stages/11370/Show/Italy-Serie-B-2014-2015'
league_season_URL['SE_2_1516'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/6015/Stages/12856/Show/Italy-Serie-B-2015-2016'
league_season_URL['SE_2_1617'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/6485/Stages/14067/Show/Italy-Serie-B-2016-2017'
league_season_URL['SE_2_1718'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/6987/Stages/15428/Show/Italy-Serie-B-2017-2018'
league_season_URL['SE_2_1819'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/7496/Stages/16595/Show/Italy-Serie-B-2018-2019'
league_season_URL['SE_2_1920'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/7952/Stages/17880/Show/Italy-Serie-B-2019-2020'
league_season_URL['SE_2_2021'] = 'https://1xbet.whoscored.com/Regions/108/Tournaments/19/Seasons/8343/Stages/18913/Show/Italy-Serie-B-2020-2021'

##### BL

league_season_URL['BL_1_1112'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/2949/Germany-Bundesliga'
league_season_URL['BL_1_1213'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/3424/Germany-Bundesliga'
league_season_URL['BL_1_1314'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/3863/Germany-Bundesliga'
league_season_URL['BL_1_1415'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/4336/Germany-Bundesliga'
league_season_URL['BL_1_1516'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/5870/Germany-Bundesliga'
league_season_URL['BL_1_1617'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/6392/Germany-Bundesliga'
league_season_URL['BL_1_1718'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/6902/Germany-Bundesliga'
league_season_URL['BL_1_1819'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/7405/Germany-Bundesliga'
league_season_URL['BL_1_1920'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/7872/Germany-Bundesliga'
league_season_URL['BL_1_2021'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/3/Seasons/8279/Germany-Bundesliga'

league_season_URL['BL_2_1112'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/2950/Germany-Bundesliga-II'
league_season_URL['BL_2_1213'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/3423/Germany-Bundesliga-II'
league_season_URL['BL_2_1314'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/3864/Germany-Bundesliga-II'
league_season_URL['BL_2_1415'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/4335/Germany-Bundesliga-II'
league_season_URL['BL_2_1516'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/5871/Germany-Bundesliga-II'
league_season_URL['BL_2_1617'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/6393/Germany-Bundesliga-II'
league_season_URL['BL_2_1718'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/6903/Germany-Bundesliga-II'
league_season_URL['BL_2_1819'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/7406/Germany-Bundesliga-II'
league_season_URL['BL_2_1920'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/7873/Germany-Bundesliga-II'
league_season_URL['BL_2_2021'] = 'https://1xbet.whoscored.com/Regions/81/Tournaments/6/Seasons/8280/Germany-Bundesliga-II'

# %%
for season in list(league_season_URL.keys()):
    temp_url = league_season_URL[season]
    try :
        temp_df = league_table(temp_url)
        file_name = 'table_' + season + '.csv'
        print(str(season+'_done'))
        temp_df.to_csv(file_name)
    except :
        print(str(season + '_오류'))
        pass
# Out:
# PL_1_1112_done
# PL_1_1213_done
# PL_1_1314_done
# PL_1_1415_done
# PL_1_1516_done
# PL_1_1617_done
# PL_1_1718_done
# PL_1_1819_done
# PL_1_1920_done
# PL_1_2021_done
# PL_2_1112_done
# PL_2_1213_done
# PL_2_1314_done
# PL_2_1415_done
# PL_2_1516_done
# PL_2_1617_done
# PL_2_1718_done
# PL_2_1819_done
# PL_2_1920_done
# PL_2_2021_done
# LIGA_1_1112_done
# LIGA_1_1213_done
# LIGA_1_1314_done
# LIGA_1_1415_done
# LIGA_1_1516_done
# LIGA_1_1617_done
# LIGA_1_1718_done
# LIGA_1_1819_done
# LIGA_1_1920_done
# LIGA_1_2021_done
# LIGA_2_1112_done
# LIGA_2_1213_done
# LIGA_2_1314_done
# LIGA_2_1415_done
# LIGA_2_1516_done
# LIGA_2_1617_done
# LIGA_2_1718_done
# LIGA_2_1819_done
# LIGA_2_1920_done
# LIGA_2_2021_done
# SE_1_1112_done
# SE_1_1213_done
# SE_1_1314_done
# SE_1_1415_done
# SE_1_1516_done
# SE_1_1617_done
# SE_1_1718_done
# SE_1_1819_done
# SE_1_1920_done
# SE_1_2021_done
# SE_2_1112_done
# SE_2_1213_done
# SE_2_1314_done
# SE_2_1415_done
# SE_2_1516_done
# SE_2_1617_done
# ...

# %%
dd
# Out:
#    team_number                team_name   P   W   D   L  GF  GA   GD Pts
# 0          167          Manchester City  38  27   5   6  83  32  +51  86
# 1           32        Manchester United  38  21  11   6  73  44  +29  74
# 2           26                Liverpool  38  20   9   9  68  42  +26  69
# 3           15                  Chelsea  38  19  10   9  58  36  +22  67
# 4           14                Leicester  38  20   6  12  68  50  +18  66
# 5           29                 West Ham  38  19   8  11  62  47  +15  65
# 6           30                Tottenham  38  18   8  12  68  45  +23  62
# 7           13                  Arsenal  38  18   7  13  55  39  +16  61
# 8           19                    Leeds  38  18   5  15  62  54   +8  59
# 9           31                  Everton  38  17   8  13  47  48   -1  59
# 10          24              Aston Villa  38  16   7  15  55  46   +9  55
# 11          23         Newcastle United  38  12   9  17  46  62  -16  45
# ...

# %%
'LIGA' in season
# Out:
# True

# %%
'LIGA' in season or 'PL' in season
# Out:
# True

# %%
season
# Out:
# 'LIGA_2_1819'

# %%
for season in list(league_season_URL.keys()):
    if 'PL' in season or 'SE_2' in season or 'LIGA' in season:
        print(str(season+'_pass'))
        pass
        
    else : 
        temp_url = league_season_URL[season]
        temp_df = team_stat_table(temp_url)
        file_name = 'Table_' + season + '.csv'
        print(str(season+'_done'))
    temp_df.to_csv(file_name)
# Out:
# PL_1_1819_pass
# PL_1_1920_pass
# PL_2_1819_pass
# PL_2_1920_pass
# LIGA_1_1819_pass
# LIGA_1_1920_pass
# LIGA_2_1819_pass
# LIGA_2_1920_pass
#             team_name Shoted pg Tackles pg Intercept pg Fouls pg Offsides pg
# 0            Juventus      11.7         15         10.4     12.4           2
# 1              Napoli      11.4       15.2          9.4     10.8         2.2
# 2            Atalanta      10.9       16.8           12     11.7         1.9
# 3                Roma      14.3       14.1           11     12.1         1.3
# 4              Torino      12.5       16.8         11.8     16.2           2
# 5               Inter      11.1       16.2          8.2     12.3         1.7
# 6            AC Milan      12.3       16.9          9.8     11.7         1.7
# 7               Lazio      12.4       17.3         11.4     13.2         2.6
# 8           Sampdoria      13.6       17.1          9.6       13         1.8
# ...

# %%
def team_stat_table(URL, api_delay_term=3):
    url = str(URL)
    driver = webdriver.Chrome('C:/Users/jaemini_man/Desktop/soccer/chromedriver')
    driver.get(url)
    
    time.sleep(api_delay_term)
    
    league_table_df = pd.DataFrame(columns=[
        "team_name", "P", "W", "D", "L", "GF", "GA", "GD", "Pts"])
    elements = driver.find_elements_by_class_name('standings')[0].find_elements_by_css_selector("tr")
    
    for element in elements:
        league_table_dict = { 
            "team_name": element.find_elements_by_css_selector("td")[0].find_elements_by_css_selector("a")[0].text,     
            "P": element.find_elements_by_css_selector("td")[1].text,
            "W": element.find_elements_by_css_selector("td")[2].text, 
            "D": element.find_elements_by_css_selector("td")[3].text,
            "L": element.find_elements_by_css_selector("td")[4].text, 
            "GF": element.find_elements_by_css_selector("td")[5].text, 
            "GA": element.find_elements_by_css_selector("td")[6].text,
            "GD": element.find_elements_by_css_selector("td")[7].text,
            "Pts": element.find_elements_by_css_selector("td")[8].text,
        }
        league_table_df.loc[len(league_table_df)] = league_table_dict
    
    time.sleep(api_delay_term)
    
    starter = driver.find_elements_by_id("sub-navigation")
    starter = starter[0].find_elements_by_css_selector("li")[2]
    starter.click()
    
    
    team_stat_df1 = pd.DataFrame(columns=[
        "team_name", "Goals", "Shots pg", "Yellow", "Red", "Poss%", "Pass%", 
        "A_Won", "Rating"
    ])
    elements = driver.find_elements_by_id("top-team-stats-summary-content")
    elements = elements[0].find_elements_by_css_selector("tr")
    
    for element in elements:
        team_table_dict1 = { 
            "team_name": element.find_elements_by_css_selector("td")[0].find_elements_by_css_selector("a")[0].text.split('. ')[1],     
            "Goals": element.find_elements_by_css_selector("td")[1].text,
            "Shots pg": element.find_elements_by_css_selector("td")[2].text, 
            "Yellow": element.find_elements_by_css_selector("td")[3].find_elements_by_css_selector("span")[0].text, 
            "Red": element.find_elements_by_css_selector("td")[3].find_elements_by_css_selector("span")[1].text, 
            "Poss%": element.find_elements_by_css_selector("td")[4].text, 
            "Pass%": element.find_elements_by_css_selector("td")[5].text,
            "A_Won": element.find_elements_by_css_selector("td")[6].text,
            "Rating": element.find_elements_by_css_selector("td")[7].text,
        }
        team_stat_df1.loc[len(team_stat_df1)] = team_table_dict1
    
    element = driver.find_element_by_css_selector("a[href='#stage-team-stats-defensive']")
    element.click()
    
    time.sleep(api_delay_term)
    
    
    team_stat_df2 = pd.DataFrame(columns=[
        "team_name", "Shoted pg", "Tackles pg", "Intercept pg", "Fouls pg", "Offsides pg"
    ])
    elements = driver.find_elements_by_id("statistics-team-table-defensive")
    elements = elements[0].find_elements_by_id("top-team-stats-summary-content")
    elements = elements[0].find_elements_by_css_selector("tr")
    
    for element in elements:
        team_table_dict2 = { 
            "team_name": element.find_elements_by_css_selector("td")[0].find_elements_by_css_selector("a")[0].text.split('. ')[1],     
            'Shoted pg': element.find_elements_by_css_selector("td")[1].text,
            'Tackles pg': element.find_elements_by_css_selector("td")[2].text,
            'Intercept pg': element.find_elements_by_css_selector("td")[3].text, 
            'Fouls pg': element.find_elements_by_css_selector("td")[4].text, 
            'Offsides pg': element.find_elements_by_css_selector("td")[5].text, 
        }
        team_stat_df2.loc[len(team_stat_df2)] = team_table_dict2
    
    element = driver.find_element_by_css_selector("a[href='#stage-team-stats-offensive']")
    element.click()
    
    time.sleep(api_delay_term)
    
    team_stat_df3 = pd.DataFrame(columns=[
        "team_name", "Shots OT pg", "Dribbles pg", "Fouled pg"
    ])
    elements = driver.find_elements_by_id("statistics-team-table-offensive")
    elements = elements[0].find_elements_by_id("top-team-stats-summary-content")
    elements = elements[0].find_elements_by_css_selector("tr")
    
    for element in elements: 
        team_table_dict3 = { 
            "team_name": element.find_elements_by_css_selector("td")[0].find_elements_by_css_selector("a")[0].text.split('. ')[1],     
            'Shots OT pg': element.find_elements_by_css_selector("td")[2].text,
            'Dribbles pg': element.find_elements_by_css_selector("td")[3].text, 
            'Fouled pg': element.find_elements_by_css_selector("td")[4].text, 
        }
        team_stat_df3.loc[len(team_stat_df3)] = team_table_dict3
        
        
    team_stat_df = pd.merge(league_table_df, team_stat_df1, how='left', on='team_name')
    team_stat_df = pd.merge(team_stat_df, team_stat_df2, how='left', on='team_name')
    team_stat_df = pd.merge(team_stat_df, team_stat_df3, how='left', on='team_name')
    
    # close webdriver
    driver.close()
    
    return team_stat_df

# %%
'. aa'.split('. ')[1]
# Out:
# 'aa'

# %%
dd = team_stat_table(league_season_URL[season])
# Out:
#             team_name Shoted pg Tackles pg Intercept pg Fouls pg Offsides pg
# 0             FC Koln      12.4       17.9         10.9     15.2         2.4
# 1           Paderborn      13.1       17.8         11.4     13.9         2.4
# 2        Union Berlin      11.7       17.1         11.1     17.7         1.4
# 3        Hamburger SV      12.4       17.2         10.8     13.1         2.2
# 4     Jahn Regensburg      14.6       19.8         12.3     16.8         2.9
# 5       FC Heidenheim      15.7       15.5         10.8     13.8         1.9
# 6              Bochum      15.2       18.3         10.9     13.6         2.5
# 7   Arminia Bielefeld      11.8       16.5         10.1     14.6         1.5
# 8       Holstein Kiel      14.2       15.6         10.2     12.6         2.6
# 9          Sandhausen      12.9       16.4         11.2     14.5         1.8
# 10                 St      13.5       17.7         11.4     13.4         2.2
# ...

# %%
dd
# Out:
#             team_name   P   W   D   L  GF  GA   GD Pts Goals  ... A_Won  \
# 0             FC Koln  34  19   6   9  84  47  +37  63    84  ...  21.8
# 1           Paderborn  34  16   9   9  76  50  +26  57    76  ...  22.7
# 2        Union Berlin  34  14  15   5  54  33  +21  57    54  ...  30.9
# 3        Hamburger SV  34  16   8  10  45  42   +3  56    45  ...  21.2
# 4       FC Heidenheim  34  15  10   9  55  45  +10  55    55  ...  23.5
# 5       Holstein Kiel  34  13  10  11  60  51   +9  49    60  ...  19.1
# 6   Arminia Bielefeld  34  13  10  11  52  50   +2  49    52  ...  28.4
# 7     Jahn Regensburg  34  12  13   9  55  54   +1  49    55  ...  29.1
# 8           St. Pauli  34  14   7  13  46  53   -7  49   NaN  ...   NaN
# 9           Darmstadt  34  13   7  14  45  53   -8  46    45  ...    24
# 10             Bochum  34  11  11  12  49  50   -1  44    49  ...  22.4
# 11     Dynamo Dresden  34  11   9  14  41  48   -7  42    41  ...  17.8
# ...
